# %% [markdown]
# # ANN CLASSIFICATION - {"CUSTOMER CHURN" DATASET}

# %% [markdown]
# # Hypertuned Models and Results

# %% [markdown]
# ## NOTE: To reproduce the same results.
# ### - Use the imports and configuration settings as it is in the order.
# ### - Datasets (Train, Valid, Test) as per the current random state (46).
# ### - Execute a specfic model individually, but comment out other model's cell. (Layers will always number from 0)

# %% [raw]
# import numpy as np
# import tensorflow as tf
# import random as rn

# %% [raw]
# import os
# os.environ['PYTHONHASHSEED'] = '0'
# rn.seed(1254)
# np.random.seed(37)
# tf.random.set_seed(89)
#
# # from keras import backend as K
# # session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
# # sess = tf.Session(graph = tf.get_default_graph(), config=session_conf)
# # K.set_session(sess)
#
# tf.compat.v1.set_random_seed(12)
# session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
# sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
# tf.compat.v1.keras.backend.set_session(sess)
#
# # tf.keras.utils.set_random_seed(1)
# # tf.config.experimental.enable_op_determinism()

# %% [raw]
# import pandas as pd
#
# import plotly.express as px
#
# import tensorflow
# from tensorflow import keras
# from tensorflow.keras import Sequential
# from keras.layers import Dense, Dropout
#
# import keras_tuner as kt
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
#
# from pickle import dump, load
#
# import warnings
# warnings.filterwarnings('ignore')
#
# from sklearn import set_config
# set_config(display='diagram')

# %% [raw]
# # PD Options
#
# pd.set_option('display.min_rows', 5)
# pd.set_option('display.max_rows', 25)
# pd.set_option('display.precision', 4)

# %% [markdown]
# ## ALL Models

# %% [raw]
# # model:1
# def model_m1():
#     model = Sequential()
#     model.add(Dense(40, activation='relu', input_dim=69))
#     model.add(Dropout(0.1))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])
#
#     return model
#
# # model:2
# def model_m2():
#     model = Sequential()
#     model.add(Dense(32, activation='relu', input_dim=69))
#     model.add(Dropout(0.5))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])
#
#     return model
#
# # model:3
# def model_m3():
#     model = Sequential()
#     model.add(Dense(48, activation='tanh', input_dim=69))
#     model.add(Dropout(0.3))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])
#
#     return model
#
# # model:4
# def model_m4():
#     model = Sequential()
#     model.add(Dense(40, activation='linear', input_dim=69))
#     model.add(Dropout(0.4))
#     model.add(Dense(48, activation='relu'))
#     model.add(Dropout(0.3))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#
#     return model
#
# # model:5
# def model_m5():
#     model = Sequential()
#     model.add(Dense(56, activation='relu', input_dim=69))
#     model.add(Dropout(0.3))
#     model.add(Dense(56, activation='tanh'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
#
#     return model
#
# # model:6
# def model_m6():
#     model = Sequential()
#     model.add(Dense(40, activation='relu', input_dim=69))
#     model.add(Dropout(0.3))
#     model.add(Dense(32, activation='tanh'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#
#     return model
#
# # model:7
# def model_m7():
#     model = Sequential()
#     model.add(Dense(64, activation='relu', input_dim=69))
#     model.add(Dropout(0.4))
#     model.add(Dense(64, activation='linear'))
#     model.add(Dropout(0.5))
#     model.add(Dense(24, activation='linear'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
#
#     return model
#
# # model:8
# def model_m8():
#     model = Sequential()
#     model.add(Dense(32, activation='relu', input_dim=69))
#     model.add(Dropout(0.1))
#     model.add(Dense(40, activation='linear'))
#     model.add(Dropout(0.1))
#     model.add(Dense(24, activation='linear'))
#     model.add(Dropout(0.1))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
#
#     return model
#
# # model:9
# def model_m9():
#     model = Sequential()
#     model.add(Dense(69, activation='relu', input_dim=69))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
#
#     return model
#
# # model:10
# def model_m10():
#     model = Sequential()
#     model.add(Dense(69, activation='relu', input_dim=69))
#     model.add(Dropout(0.1))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])
#
#     return model
#
# # model:11
# def model_m11():
#     model = Sequential()
#     model.add(Dense(35, activation='relu', input_dim=69))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])
#
#     return model
#
# # model:12
# def model_m12():
#     model = Sequential()
#     model.add(Dense(69, activation='relu', input_dim=69))
#     model.add(Dropout(0.1))
#     model.add(Dense(35, activation='relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#
#     return model
#
# # model:13
# def model_m13():
#     model = Sequential()
#     model.add(Dense(50, activation='relu', input_dim=69))
#     model.add(Dropout(0.3))
#     model.add(Dense(25, activation='relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
#
#     return model
#
# # model:14
# def model_m14():
#     model = Sequential()
#     model.add(Dense(35, activation='relu', input_dim=69))
#     model.add(Dropout(0.3))
#     model.add(Dense(18, activation='relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#
#     return model

# %% [markdown]
# ## ALL Results

# %% [raw]
# M1: epochs(31)   -----------------------------
# Train Dataset Accuracy : 96.408 %
# Validation Dataset Accuracy : 96.0 %
#
# M2: epochs(81) -------------------------------
# Train Dataset Accuracy : 96.2787 %
# Validation Dataset Accuracy : 96.0 %
#
# M3: epochs(81) -------------------------------
# Train Dataset Accuracy : 95.2299 %
# Validation Dataset Accuracy : 96.0 %
#
# M4: epochs(55) -------------------------------
# Train Dataset Accuracy : 95.0287 %
# Validation Dataset Accuracy : 95.0 %
#
# M5: epochs(14) -------------------------------
# Train Dataset Accuracy : 94.6264 %
# Validation Dataset Accuracy : 94.0 %
#
# M6: epochs(21) -------------------------------
# Train Dataset Accuracy : 97.0546 %
# Validation Dataset Accuracy : 96.0 %
#
# M7: epochs(15) -------------------------------
# Train Dataset Accuracy : 94.6552 %
# Validation Dataset Accuracy : 95.0 %
#
# M8: epochs(19) -------------------------------
# Train Dataset Accuracy : 95.8764 %
# Validation Dataset Accuracy : 95.0 %
#
# M9: epochs(16)  ------------------------------
# Train Dataset Accuracy : 96.0057 %
# Validation Dataset Accuracy : 95.0 %
#
# M10: epochs(21)  ------------------------------
# Train Dataset Accuracy : 96.2213 %
# Validation Dataset Accuracy : 95.0 %
#
# M11: epochs(38)  ------------------------------
# Train Dataset Accuracy : 96.2931 %
# Validation Dataset Accuracy : 95.0 %
#
# M12: epochs(13)  ------------------------------
# Train Dataset Accuracy : 97.8448 %
# Validation Dataset Accuracy : 96.0 %
#
# M13: epochs(20) -------------------------------
# Train Dataset Accuracy : 94.9282 %
# Validation Dataset Accuracy : 94.0 %
#
# M14: epochs(25) -------------------------------
# Train Dataset Accuracy : 97.0115 %
# Validation Dataset Accuracy : 96.0 %

# %% [markdown]
# ## Models with max validation accuracy

# %% [raw]
# M1: epochs(31)   -----------------------------
# Train Dataset Accuracy : 96.408 %
# Validation Dataset Accuracy : 96.0 %
#
# M2: epochs(81) -------------------------------
# Train Dataset Accuracy : 96.2787 %
# Validation Dataset Accuracy : 96.0 %
#
# M6: epochs(21) -------------------------------
# Train Dataset Accuracy : 97.0546 %
# Validation Dataset Accuracy : 96.0 %
#
# M12: epochs(13)  ------------------------------
# Train Dataset Accuracy : 97.8448 %
# Validation Dataset Accuracy : 96.0 %
#
# M14: epochs(25) -------------------------------
# Train Dataset Accuracy : 97.0115 %
# Validation Dataset Accuracy : 96.0 %

# %% [markdown]
# ## Model with minimum difference between train and validation accuracy (to avoid overfitting)

# %% [raw]
# # model:2
# def model_m2():
#     model = Sequential()
#     model.add(Dense(32, activation='relu', input_dim=69))
#     model.add(Dropout(0.5))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])
#
#     return model
#
#
# M2: epochs(81) -------------------------------
# Train Dataset Accuracy : 96.2787 %
# Validation Dataset Accuracy : 96.0 %
